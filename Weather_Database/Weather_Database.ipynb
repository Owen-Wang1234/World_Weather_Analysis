# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 791

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dusi
# Processing Record 2 of Set 1 | puerto colombia
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | westport
# Processing Record 6 of Set 1 | burica
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kharp
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | warrington
# Processing Record 15 of Set 1 | tingrela
# City not found. Skipping...
# Processing Record 16 of Set 1 | vuktyl
# Processing Record 17 of Set 1 | turayf
# Processing Record 18 of Set 1 | belmonte
# Processing Record 19 of Set 1 | muros
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | maiduguri
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | san juan bautista
# Processing Record 28 of Set 1 | sayat
# Processing Record 29 of Set 1 | necochea
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | chissamba
# Processing Record 33 of Set 1 | emmaus
# Processing Record 34 of Set 1 | nagua
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | gweta
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | barcelos
# Processing Record 40 of Set 1 | kibre mengist
# Processing Record 41 of Set 1 | padang
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | ashtian
# Processing Record 47 of Set 1 | mitsamiouli
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | zamora
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | praia da vitoria
# Processing Record 2 of Set 2 | kidal
# Processing Record 3 of Set 2 | pinyug
# Processing Record 4 of Set 2 | guaxupe
# Processing Record 5 of Set 2 | kem
# Processing Record 6 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 2 | sorland
# Processing Record 8 of Set 2 | touros
# Processing Record 9 of Set 2 | tonantins
# Processing Record 10 of Set 2 | ginir
# Processing Record 11 of Set 2 | yazman
# Processing Record 12 of Set 2 | dehloran
# Processing Record 13 of Set 2 | aksarka
# Processing Record 14 of Set 2 | wamba
# Processing Record 15 of Set 2 | praia
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | riyadh
# Processing Record 18 of Set 2 | qostanay
# Processing Record 19 of Set 2 | vardo
# Processing Record 20 of Set 2 | porto novo
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | tazovskiy
# Processing Record 23 of Set 2 | axim
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | alta floresta
# Processing Record 26 of Set 2 | cagliari
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | lagoa
# Processing Record 29 of Set 2 | tocopilla
# Processing Record 30 of Set 2 | antalya
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | la baneza
# Processing Record 33 of Set 2 | chuy
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | cabedelo
# Processing Record 36 of Set 2 | raul soares
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | caraballeda
# Processing Record 39 of Set 2 | new glasgow
# Processing Record 40 of Set 2 | lebedyan
# Processing Record 41 of Set 2 | sur
# Processing Record 42 of Set 2 | adzope
# Processing Record 43 of Set 2 | abeche
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | saint-leu
# Processing Record 46 of Set 2 | lima
# Processing Record 47 of Set 2 | salalah
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | melilla
# Processing Record 1 of Set 3 | bahia blanca
# Processing Record 2 of Set 3 | ajdabiya
# Processing Record 3 of Set 3 | wagar
# Processing Record 4 of Set 3 | mehamn
# Processing Record 5 of Set 3 | oussouye
# Processing Record 6 of Set 3 | roald
# Processing Record 7 of Set 3 | general roca
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | yarada
# Processing Record 11 of Set 3 | kanata
# Processing Record 12 of Set 3 | starkville
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | dubovskoye
# Processing Record 15 of Set 3 | khash
# Processing Record 16 of Set 3 | kumluca
# Processing Record 17 of Set 3 | muisne
# Processing Record 18 of Set 3 | eyl
# Processing Record 19 of Set 3 | chupa
# Processing Record 20 of Set 3 | balta
# Processing Record 21 of Set 3 | padilla
# Processing Record 22 of Set 3 | bonavista
# Processing Record 23 of Set 3 | tarnobrzeg
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | vihari
# Processing Record 28 of Set 3 | marsaxlokk
# Processing Record 29 of Set 3 | touba
# Processing Record 30 of Set 3 | conde
# Processing Record 31 of Set 3 | koslan
# Processing Record 32 of Set 3 | vercheres
# Processing Record 33 of Set 3 | kaka
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | haysyn
# Processing Record 36 of Set 3 | saldanha
# Processing Record 37 of Set 3 | zhanaozen
# Processing Record 38 of Set 3 | comodoro rivadavia
# Processing Record 39 of Set 3 | katiola
# Processing Record 40 of Set 3 | chapais
# Processing Record 41 of Set 3 | cayenne
# Processing Record 42 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 3 | marzuq
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | zlobin
# Processing Record 46 of Set 3 | larsnes
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | nouadhibou
# Processing Record 49 of Set 3 | prieska
# Processing Record 50 of Set 3 | huittinen
# Processing Record 1 of Set 4 | barkhan
# Processing Record 2 of Set 4 | vigrestad
# Processing Record 3 of Set 4 | severodvinsk
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | sinnamary
# Processing Record 8 of Set 4 | saint-augustin
# Processing Record 9 of Set 4 | kavaratti
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | adre
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | sao joao da barra
# Processing Record 14 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | sao miguel do araguaia
# Processing Record 17 of Set 4 | zorritos
# Processing Record 18 of Set 4 | leshukonskoye
# Processing Record 19 of Set 4 | korhogo
# Processing Record 20 of Set 4 | nouakchott
# Processing Record 21 of Set 4 | mwense
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | arlit
# Processing Record 26 of Set 4 | allapalli
# Processing Record 27 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 4 | jardim
# Processing Record 29 of Set 4 | olinda
# Processing Record 30 of Set 4 | takoradi
# Processing Record 31 of Set 4 | lubumbashi
# Processing Record 32 of Set 4 | lujan
# Processing Record 33 of Set 4 | la asuncion
# Processing Record 34 of Set 4 | taoudenni
# Processing Record 35 of Set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | longyearbyen
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | valky
# Processing Record 40 of Set 4 | ronne
# Processing Record 41 of Set 4 | bozoum
# Processing Record 42 of Set 4 | caravelas
# Processing Record 43 of Set 4 | inhambane
# Processing Record 44 of Set 4 | somogyvar
# Processing Record 45 of Set 4 | piacabucu
# Processing Record 46 of Set 4 | puri
# Processing Record 47 of Set 4 | murgab
# Processing Record 48 of Set 4 | riachao
# Processing Record 49 of Set 4 | calama
# Processing Record 50 of Set 4 | tambacounda
# Processing Record 1 of Set 5 | surbo
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | arrecife
# Processing Record 4 of Set 5 | turtas
# Processing Record 5 of Set 5 | vezirkopru
# Processing Record 6 of Set 5 | barahona
# Processing Record 7 of Set 5 | chitral
# Processing Record 8 of Set 5 | paramonga
# Processing Record 9 of Set 5 | strezhevoy
# Processing Record 10 of Set 5 | preobrazhenka
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | sakhnovshchyna
# Processing Record 13 of Set 5 | sept-iles
# Processing Record 14 of Set 5 | soure
# Processing Record 15 of Set 5 | san cristobal
# Processing Record 16 of Set 5 | ucar
# Processing Record 17 of Set 5 | russkiy kameshkir
# Processing Record 18 of Set 5 | hambantota
# Processing Record 19 of Set 5 | oranjemund
# Processing Record 20 of Set 5 | porto walter
# Processing Record 21 of Set 5 | tshane
# Processing Record 22 of Set 5 | marrakesh
# Processing Record 23 of Set 5 | dwarka
# Processing Record 24 of Set 5 | benton harbor
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | magaria
# Processing Record 27 of Set 5 | neuquen
# Processing Record 28 of Set 5 | ossipee
# Processing Record 29 of Set 5 | rundu
# Processing Record 30 of Set 5 | hamilton
# Processing Record 31 of Set 5 | huancabamba
# Processing Record 32 of Set 5 | santa cruz
# Processing Record 33 of Set 5 | plettenberg bay
# Processing Record 34 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 5 | pirai do sul
# Processing Record 36 of Set 5 | jaisalmer
# Processing Record 37 of Set 5 | santiago del estero
# Processing Record 38 of Set 5 | saint george
# Processing Record 39 of Set 5 | peniche
# Processing Record 40 of Set 5 | mormugao
# Processing Record 41 of Set 5 | bara
# Processing Record 42 of Set 5 | natitingou
# Processing Record 43 of Set 5 | umm kaddadah
# Processing Record 44 of Set 5 | tarifa
# Processing Record 45 of Set 5 | zholymbet
# Processing Record 46 of Set 5 | ergani
# Processing Record 47 of Set 5 | nyuksenitsa
# Processing Record 48 of Set 5 | cockburn town
# Processing Record 49 of Set 5 | virginia beach
# Processing Record 50 of Set 5 | kolyvan
# Processing Record 1 of Set 6 | sandwick
# Processing Record 2 of Set 6 | turukhansk
# Processing Record 3 of Set 6 | velenje
# Processing Record 4 of Set 6 | vargashi
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | lere
# Processing Record 7 of Set 6 | enschede
# Processing Record 8 of Set 6 | bereda
# Processing Record 9 of Set 6 | elmina
# Processing Record 10 of Set 6 | fontaine
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | puerto ayora
# Processing Record 13 of Set 6 | la palma
# Processing Record 14 of Set 6 | manati
# Processing Record 15 of Set 6 | rawson
# Processing Record 16 of Set 6 | tanout
# Processing Record 17 of Set 6 | ipixuna
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | cap-aux-meules
# Processing Record 20 of Set 6 | abu dhabi
# Processing Record 21 of Set 6 | georgetown
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | longonjo
# Processing Record 24 of Set 6 | calvia
# Processing Record 25 of Set 6 | antofagasta
# Processing Record 26 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 6 | araouane
# Processing Record 28 of Set 6 | hualmay
# Processing Record 29 of Set 6 | veraval
# Processing Record 30 of Set 6 | sabla
# Processing Record 31 of Set 6 | uige
# Processing Record 32 of Set 6 | borovskoy
# Processing Record 33 of Set 6 | granger
# Processing Record 34 of Set 6 | khor
# Processing Record 35 of Set 6 | sergeyevka
# Processing Record 36 of Set 6 | manaure
# Processing Record 37 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 6 | birur
# Processing Record 39 of Set 6 | taldom
# Processing Record 40 of Set 6 | sal rei
# Processing Record 41 of Set 6 | villanueva de cordoba
# Processing Record 42 of Set 6 | santa rosa del sur
# Processing Record 43 of Set 6 | timra
# Processing Record 44 of Set 6 | rock sound
# Processing Record 45 of Set 6 | dalmau
# Processing Record 46 of Set 6 | ponce
# Processing Record 47 of Set 6 | salym
# Processing Record 48 of Set 6 | kattivakkam
# Processing Record 49 of Set 6 | iquitos
# Processing Record 50 of Set 6 | aurad
# Processing Record 1 of Set 7 | ullapool
# Processing Record 2 of Set 7 | kingston
# Processing Record 3 of Set 7 | jurm
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | presidente bernardes
# Processing Record 6 of Set 7 | barranca
# Processing Record 7 of Set 7 | oktyabrskoye
# Processing Record 8 of Set 7 | bonfim
# Processing Record 9 of Set 7 | qobustan
# Processing Record 10 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 7 | camopi
# Processing Record 12 of Set 7 | talcahuano
# Processing Record 13 of Set 7 | angoche
# Processing Record 14 of Set 7 | vangaindrano
# Processing Record 15 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 7 | alta
# Processing Record 17 of Set 7 | kassala
# Processing Record 18 of Set 7 | colares
# Processing Record 19 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 7 | kuznetsk
# Processing Record 21 of Set 7 | oyem
# Processing Record 22 of Set 7 | umm lajj
# Processing Record 23 of Set 7 | brae
# Processing Record 24 of Set 7 | yenagoa
# Processing Record 25 of Set 7 | duki
# Processing Record 26 of Set 7 | raghunathpur
# Processing Record 27 of Set 7 | monrovia
# Processing Record 28 of Set 7 | saint-georges
# Processing Record 29 of Set 7 | hwange
# Processing Record 30 of Set 7 | sinazongwe
# Processing Record 31 of Set 7 | papayal
# Processing Record 32 of Set 7 | matay
# Processing Record 33 of Set 7 | gat
# Processing Record 34 of Set 7 | kisangani
# Processing Record 35 of Set 7 | quatre cocos
# Processing Record 36 of Set 7 | dzerzhinsk
# Processing Record 37 of Set 7 | altay
# Processing Record 38 of Set 7 | calabozo
# Processing Record 39 of Set 7 | raga
# Processing Record 40 of Set 7 | bid
# City not found. Skipping...
# Processing Record 41 of Set 7 | igarka
# Processing Record 42 of Set 7 | torrijos
# Processing Record 43 of Set 7 | rio cuarto
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | tromso
# Processing Record 46 of Set 7 | bergerac
# Processing Record 47 of Set 7 | porto belo
# Processing Record 48 of Set 7 | contamana
# Processing Record 49 of Set 7 | shiraz
# Processing Record 50 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 8 | cacador
# Processing Record 2 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 8 | san ramon de la nueva oran
# Processing Record 4 of Set 8 | matagami
# Processing Record 5 of Set 8 | ambilobe
# Processing Record 6 of Set 8 | madingou
# Processing Record 7 of Set 8 | filadelfia
# Processing Record 8 of Set 8 | santa barbara
# Processing Record 9 of Set 8 | nossa senhora das dores
# Processing Record 10 of Set 8 | thompson
# Processing Record 11 of Set 8 | oneonta
# Processing Record 12 of Set 8 | ornskoldsvik
# Processing Record 13 of Set 8 | dudinka
# Processing Record 14 of Set 8 | west bay
# Processing Record 15 of Set 8 | tucuman
# Processing Record 16 of Set 8 | burlington
# Processing Record 17 of Set 8 | turbat
# Processing Record 18 of Set 8 | saint anthony
# Processing Record 19 of Set 8 | atar
# Processing Record 20 of Set 8 | jalu
# Processing Record 21 of Set 8 | thinadhoo
# Processing Record 22 of Set 8 | rulenge
# Processing Record 23 of Set 8 | maarianhamina
# Processing Record 24 of Set 8 | menongue
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | cururupu
# Processing Record 27 of Set 8 | benicarlo
# Processing Record 28 of Set 8 | maniitsoq
# Processing Record 29 of Set 8 | carnarvon
# Processing Record 30 of Set 8 | santa marta
# Processing Record 31 of Set 8 | chaparral
# Processing Record 32 of Set 8 | shahabad
# Processing Record 33 of Set 8 | usinsk
# Processing Record 34 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 8 | abadiania
# Processing Record 36 of Set 8 | imbituba
# Processing Record 37 of Set 8 | bardejov
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | gao
# Processing Record 40 of Set 8 | eirunepe
# Processing Record 41 of Set 8 | lovozero
# Processing Record 42 of Set 8 | foso
# Processing Record 43 of Set 8 | krasnoselkup
# Processing Record 44 of Set 8 | gamboula
# Processing Record 45 of Set 8 | aripuana
# Processing Record 46 of Set 8 | hobyo
# Processing Record 47 of Set 8 | manama
# Processing Record 48 of Set 8 | skelleftea
# Processing Record 49 of Set 8 | carballo
# Processing Record 50 of Set 8 | fuengirola
# Processing Record 1 of Set 9 | tobermory
# Processing Record 2 of Set 9 | caxito
# Processing Record 3 of Set 9 | akdepe
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | lasa
# Processing Record 6 of Set 9 | kirkland lake
# Processing Record 7 of Set 9 | coquimbo
# Processing Record 8 of Set 9 | doka
# Processing Record 9 of Set 9 | skjervoy
# Processing Record 10 of Set 9 | berlevag
# Processing Record 11 of Set 9 | raudeberg
# Processing Record 12 of Set 9 | morlenbach
# Processing Record 13 of Set 9 | kaduqli
# Processing Record 14 of Set 9 | salekhard
# Processing Record 15 of Set 9 | cap malheureux
# Processing Record 16 of Set 9 | hit
# Processing Record 17 of Set 9 | demirci
# Processing Record 18 of Set 9 | naryan-mar
# Processing Record 19 of Set 9 | rio gallegos
# Processing Record 20 of Set 9 | warner robins
# Processing Record 21 of Set 9 | mikulov
# Processing Record 22 of Set 9 | bunia
# Processing Record 23 of Set 9 | gnjilane
# Processing Record 24 of Set 9 | kitob
# Processing Record 25 of Set 9 | russkaya polyana
# Processing Record 26 of Set 9 | thunder bay
# Processing Record 27 of Set 9 | straznice
# Processing Record 28 of Set 9 | whitehaven
# Processing Record 29 of Set 9 | ostrovnoy
# Processing Record 30 of Set 9 | yei
# Processing Record 31 of Set 9 | bria
# Processing Record 32 of Set 9 | lyskovo
# Processing Record 33 of Set 9 | cayambe
# Processing Record 34 of Set 9 | muli
# Processing Record 35 of Set 9 | rocha
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | khanpur
# Processing Record 38 of Set 9 | lupiro
# Processing Record 39 of Set 9 | juruti
# Processing Record 40 of Set 9 | bratislava
# Processing Record 41 of Set 9 | bafata
# Processing Record 42 of Set 9 | gumdag
# Processing Record 43 of Set 9 | otavi
# Processing Record 44 of Set 9 | glyadyanskoye
# Processing Record 45 of Set 9 | liwale
# Processing Record 46 of Set 9 | machacamarca
# Processing Record 47 of Set 9 | segou
# Processing Record 48 of Set 9 | zharkent
# Processing Record 49 of Set 9 | bosaso
# Processing Record 50 of Set 9 | smila
# Processing Record 1 of Set 10 | henties bay
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | adrar
# Processing Record 4 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 10 | port hawkesbury
# Processing Record 6 of Set 10 | zaysan
# Processing Record 7 of Set 10 | sao gabriel
# Processing Record 8 of Set 10 | acandi
# Processing Record 9 of Set 10 | stokmarknes
# Processing Record 10 of Set 10 | lokosovo
# Processing Record 11 of Set 10 | komatipoort
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | zubtsov
# Processing Record 14 of Set 10 | veszprem
# Processing Record 15 of Set 10 | pucallpa
# Processing Record 16 of Set 10 | aktash
# Processing Record 17 of Set 10 | atasu
# Processing Record 18 of Set 10 | kamenka
# Processing Record 19 of Set 10 | mao
# Processing Record 20 of Set 10 | minsk
# Processing Record 21 of Set 10 | iskandar
# Processing Record 22 of Set 10 | kolpashevo
# Processing Record 23 of Set 10 | camapua
# Processing Record 24 of Set 10 | jacareacanga
# Processing Record 25 of Set 10 | san luis
# Processing Record 26 of Set 10 | buraydah
# Processing Record 27 of Set 10 | sasovo
# Processing Record 28 of Set 10 | bandarbeyla
# Processing Record 29 of Set 10 | kostomuksha
# Processing Record 30 of Set 10 | sao geraldo do araguaia
# Processing Record 31 of Set 10 | acari
# Processing Record 32 of Set 10 | mocuba
# Processing Record 33 of Set 10 | beyneu
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | araguaina
# Processing Record 36 of Set 10 | stara vyzhivka
# Processing Record 37 of Set 10 | santa rosa
# Processing Record 38 of Set 10 | san joaquin
# Processing Record 39 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 10 | kastrakion
# Processing Record 41 of Set 10 | zhanakorgan
# Processing Record 42 of Set 10 | mineros
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | fomboni
# Processing Record 45 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 10 | havoysund
# Processing Record 47 of Set 10 | tefe
# Processing Record 48 of Set 10 | tartagal
# Processing Record 49 of Set 10 | kusa
# Processing Record 50 of Set 10 | norwalk
# Processing Record 1 of Set 11 | asosa
# Processing Record 2 of Set 11 | deer lake
# Processing Record 3 of Set 11 | kamina
# Processing Record 4 of Set 11 | gamba
# Processing Record 5 of Set 11 | dakoro
# Processing Record 6 of Set 11 | samorin
# Processing Record 7 of Set 11 | neos marmaras
# Processing Record 8 of Set 11 | saint-michel-des-saints
# Processing Record 9 of Set 11 | tres arroyos
# Processing Record 10 of Set 11 | amapa
# Processing Record 11 of Set 11 | mongoumba
# Processing Record 12 of Set 11 | margate
# Processing Record 13 of Set 11 | algiers
# Processing Record 14 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 11 | khandbari
# Processing Record 16 of Set 11 | gollere
# City not found. Skipping...
# Processing Record 17 of Set 11 | mana
# Processing Record 18 of Set 11 | yining
# Processing Record 19 of Set 11 | aras
# Processing Record 20 of Set 11 | puksoozero
# Processing Record 21 of Set 11 | pitimbu
# Processing Record 22 of Set 11 | edd
# Processing Record 23 of Set 11 | albion
# Processing Record 24 of Set 11 | sisimiut
# Processing Record 25 of Set 11 | biltine
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | karera
# Processing Record 28 of Set 11 | vagur
# Processing Record 29 of Set 11 | grand gaube
# Processing Record 30 of Set 11 | tiznit
# Processing Record 31 of Set 11 | porto empedocle
# Processing Record 32 of Set 11 | nizwa
# Processing Record 33 of Set 11 | balkhash
# Processing Record 34 of Set 11 | sechura
# Processing Record 35 of Set 11 | nadvoitsy
# Processing Record 36 of Set 11 | carauari
# Processing Record 37 of Set 11 | ushtobe
# Processing Record 38 of Set 11 | mbandaka
# Processing Record 39 of Set 11 | koungheul
# Processing Record 40 of Set 11 | abha
# Processing Record 41 of Set 11 | santarem
# Processing Record 42 of Set 11 | boueni
# Processing Record 43 of Set 11 | inirida
# Processing Record 44 of Set 11 | balsas
# Processing Record 45 of Set 11 | gelemso
# Processing Record 46 of Set 11 | omboue
# Processing Record 47 of Set 11 | ler
# Processing Record 48 of Set 11 | polunochnoye
# Processing Record 49 of Set 11 | sabzevar
# Processing Record 50 of Set 11 | nikolskoye
# Processing Record 1 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 12 | valparaiso
# Processing Record 3 of Set 12 | bitkine
# Processing Record 4 of Set 12 | tavda
# Processing Record 5 of Set 12 | bardiyah
# Processing Record 6 of Set 12 | clyde river
# Processing Record 7 of Set 12 | nokia
# Processing Record 8 of Set 12 | esil
# Processing Record 9 of Set 12 | quibdo
# Processing Record 10 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 12 | alexandria
# Processing Record 12 of Set 12 | luau
# Processing Record 13 of Set 12 | roanne
# Processing Record 14 of Set 12 | tigzirt
# Processing Record 15 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 12 | arica
# Processing Record 17 of Set 12 | los llanos de aridane
# Processing Record 18 of Set 12 | labrea
# Processing Record 19 of Set 12 | benguela
# Processing Record 20 of Set 12 | kajaani
# Processing Record 21 of Set 12 | moose factory
# Processing Record 22 of Set 12 | pozo colorado
# Processing Record 23 of Set 12 | port blair
# Processing Record 24 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 12 | umea
# Processing Record 26 of Set 12 | san vicente
# Processing Record 27 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 28 of Set 12 | bocas del toro
# Processing Record 29 of Set 12 | podporozhye
# Processing Record 30 of Set 12 | knysna
# Processing Record 31 of Set 12 | aswan
# Processing Record 32 of Set 12 | lodeynoye pole
# Processing Record 33 of Set 12 | mount pleasant
# Processing Record 34 of Set 12 | porto murtinho
# Processing Record 35 of Set 12 | khorixas
# Processing Record 36 of Set 12 | dutlwe
# Processing Record 37 of Set 12 | luanda
# Processing Record 38 of Set 12 | dakar
# Processing Record 39 of Set 12 | bakel
# Processing Record 40 of Set 12 | novovasylivka
# Processing Record 41 of Set 12 | matara
# Processing Record 42 of Set 12 | kalmunai
# Processing Record 43 of Set 12 | la rioja
# Processing Record 44 of Set 12 | sandviken
# Processing Record 45 of Set 12 | kaputa
# Processing Record 46 of Set 12 | japura
# Processing Record 47 of Set 12 | cambuquira
# Processing Record 48 of Set 12 | bubaque
# Processing Record 49 of Set 12 | faro
# Processing Record 50 of Set 12 | camocim
# Processing Record 1 of Set 13 | guatire
# Processing Record 2 of Set 13 | bilma
# Processing Record 3 of Set 13 | athens
# Processing Record 4 of Set 13 | cervo
# Processing Record 5 of Set 13 | barra do corda
# Processing Record 6 of Set 13 | mubende
# Processing Record 7 of Set 13 | ekibastuz
# Processing Record 8 of Set 13 | nyazepetrovsk
# Processing Record 9 of Set 13 | keti bandar
# Processing Record 10 of Set 13 | mahanoro
# Processing Record 11 of Set 13 | franca
# Processing Record 12 of Set 13 | beboto
# Processing Record 13 of Set 13 | ormara
# Processing Record 14 of Set 13 | paamiut
# Processing Record 15 of Set 13 | vila franca do campo
# Processing Record 16 of Set 13 | tshikapa
# Processing Record 17 of Set 13 | acarau
# Processing Record 18 of Set 13 | chor
# Processing Record 19 of Set 13 | teseney
# Processing Record 20 of Set 13 | korla
# Processing Record 21 of Set 13 | laguna de perlas
# Processing Record 22 of Set 13 | banswada
# Processing Record 23 of Set 13 | boende
# Processing Record 24 of Set 13 | wahlstedt
# Processing Record 25 of Set 13 | erin
# Processing Record 26 of Set 13 | danielskuil
# Processing Record 27 of Set 13 | guaratinga
# Processing Record 28 of Set 13 | tena
# Processing Record 29 of Set 13 | havre-saint-pierre
# Processing Record 30 of Set 13 | awbari
# Processing Record 31 of Set 13 | tulum
# Processing Record 32 of Set 13 | caiaponia
# Processing Record 33 of Set 13 | fort walton beach
# Processing Record 34 of Set 13 | vallentuna
# Processing Record 35 of Set 13 | malakal
# Processing Record 36 of Set 13 | teguldet
# Processing Record 37 of Set 13 | binga
# Processing Record 38 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 39 of Set 13 | rafsanjan
# Processing Record 40 of Set 13 | afua
# Processing Record 41 of Set 13 | bouca
# Processing Record 42 of Set 13 | pangnirtung
# Processing Record 43 of Set 13 | el perico
# Processing Record 44 of Set 13 | chigorodo
# Processing Record 45 of Set 13 | vestmannaeyjar
# Processing Record 46 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 47 of Set 13 | leo
# Processing Record 48 of Set 13 | bandiagara
# Processing Record 49 of Set 13 | nantucket
# Processing Record 50 of Set 13 | salta
# Processing Record 1 of Set 14 | baghdad
# Processing Record 2 of Set 14 | takestan
# Processing Record 3 of Set 14 | bressanone
# Processing Record 4 of Set 14 | kilinochchi
# Processing Record 5 of Set 14 | mogadishu
# Processing Record 6 of Set 14 | kwekwe
# Processing Record 7 of Set 14 | tremedal
# Processing Record 8 of Set 14 | sao gabriel da cachoeira
# Processing Record 9 of Set 14 | rincon
# Processing Record 10 of Set 14 | spring hill
# Processing Record 11 of Set 14 | inverness
# Processing Record 12 of Set 14 | lastoursville
# Processing Record 13 of Set 14 | mbala
# Processing Record 14 of Set 14 | vallenar
# Processing Record 15 of Set 14 | eyemouth
# Processing Record 16 of Set 14 | sanchor
# Processing Record 17 of Set 14 | bavly
# Processing Record 18 of Set 14 | ponta delgada
# Processing Record 19 of Set 14 | mabaruma
# Processing Record 20 of Set 14 | kardailovo
# Processing Record 21 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 14 | songea
# Processing Record 23 of Set 14 | puerto ayacucho
# Processing Record 24 of Set 14 | lamu
# Processing Record 25 of Set 14 | buchanan
# Processing Record 26 of Set 14 | casablanca
# Processing Record 27 of Set 14 | san-pedro
# Processing Record 28 of Set 14 | la libertad
# Processing Record 29 of Set 14 | saquarema
# Processing Record 30 of Set 14 | inzer
# Processing Record 31 of Set 14 | carutapera
# Processing Record 32 of Set 14 | jabinyanah
# Processing Record 33 of Set 14 | tingi
# Processing Record 34 of Set 14 | wilmington
# Processing Record 35 of Set 14 | matadi
# Processing Record 36 of Set 14 | bibiani
# Processing Record 37 of Set 14 | mayumba
# Processing Record 38 of Set 14 | nara
# Processing Record 39 of Set 14 | rawah
# Processing Record 40 of Set 14 | ugoofaaru
# Processing Record 41 of Set 14 | huarmey
# Processing Record 42 of Set 14 | shetpe
# Processing Record 43 of Set 14 | teguise
# Processing Record 44 of Set 14 | agirish
# Processing Record 45 of Set 14 | chokwe
# Processing Record 46 of Set 14 | ilawe
# Processing Record 47 of Set 14 | kaffrine
# Processing Record 48 of Set 14 | morant bay
# Processing Record 49 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 50 of Set 14 | hammerfest
# Processing Record 1 of Set 15 | dabola
# Processing Record 2 of Set 15 | andenes
# Processing Record 3 of Set 15 | saveh
# Processing Record 4 of Set 15 | concepcion
# Processing Record 5 of Set 15 | san borja
# Processing Record 6 of Set 15 | vitkov
# Processing Record 7 of Set 15 | dublin
# Processing Record 8 of Set 15 | havelock
# Processing Record 9 of Set 15 | kharovsk
# Processing Record 10 of Set 15 | scarborough
# Processing Record 11 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 15 | mamallapuram
# Processing Record 13 of Set 15 | pyaozerskiy
# Processing Record 14 of Set 15 | poselki
# Processing Record 15 of Set 15 | norton
# Processing Record 16 of Set 15 | almendralejo
# Processing Record 17 of Set 15 | morros
# Processing Record 18 of Set 15 | salinopolis
# Processing Record 19 of Set 15 | mirnyy
# Processing Record 20 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 21 of Set 15 | mantua
# Processing Record 22 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 15 | nasturelu
# Processing Record 24 of Set 15 | mananjary
# Processing Record 25 of Set 15 | shaki
# Processing Record 26 of Set 15 | plouzane
# Processing Record 27 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 15 | dalbeattie
# Processing Record 29 of Set 15 | gobabis
# Processing Record 30 of Set 15 | mecca
# Processing Record 31 of Set 15 | ati
# Processing Record 32 of Set 15 | chingola
# Processing Record 33 of Set 15 | gorkovskiy
# Processing Record 34 of Set 15 | troitsko-pechorsk
# Processing Record 35 of Set 15 | tambopata
# Processing Record 36 of Set 15 | dapaong
# Processing Record 37 of Set 15 | naranjal
# Processing Record 38 of Set 15 | conchas
# Processing Record 39 of Set 15 | abu kamal
# Processing Record 40 of Set 15 | liverpool
# Processing Record 41 of Set 15 | mozhga
# Processing Record 42 of Set 15 | lochmaben
# Processing Record 43 of Set 15 | wexford
# Processing Record 44 of Set 15 | campos belos
# Processing Record 45 of Set 15 | nacala
# Processing Record 46 of Set 15 | gazojak
# Processing Record 47 of Set 15 | kiruna
# Processing Record 48 of Set 15 | yabrud
# Processing Record 49 of Set 15 | presidencia roque saenz pena
# Processing Record 50 of Set 15 | yelkhovka
# Processing Record 1 of Set 16 | manadhoo
# Processing Record 2 of Set 16 | eskasem
# City not found. Skipping...
# Processing Record 3 of Set 16 | atyrau
# Processing Record 4 of Set 16 | naberera
# Processing Record 5 of Set 16 | krasnogvardeyskiy
# Processing Record 6 of Set 16 | constantine
# Processing Record 7 of Set 16 | manjacaze
# Processing Record 8 of Set 16 | nata
# Processing Record 9 of Set 16 | bani
# Processing Record 10 of Set 16 | morristown
# Processing Record 11 of Set 16 | el alto
# Processing Record 12 of Set 16 | illapel
# Processing Record 13 of Set 16 | nortelandia
# Processing Record 14 of Set 16 | varhaug
# Processing Record 15 of Set 16 | chotila
# Processing Record 16 of Set 16 | chaumont
# Processing Record 17 of Set 16 | asuncion
# Processing Record 18 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 16 | gouvy
# Processing Record 20 of Set 16 | palmas
# Processing Record 21 of Set 16 | elizabeth city
# Processing Record 22 of Set 16 | odweyne
# Processing Record 23 of Set 16 | paita
# Processing Record 24 of Set 16 | campo de criptana
# Processing Record 25 of Set 16 | quelimane
# Processing Record 26 of Set 16 | kosh-agach
# Processing Record 27 of Set 16 | stryy
# City not found. Skipping...
# Processing Record 28 of Set 16 | carai
# Processing Record 29 of Set 16 | road town
# Processing Record 30 of Set 16 | borgo san dalmazzo
# Processing Record 31 of Set 16 | ballina
# Processing Record 32 of Set 16 | torit
# Processing Record 33 of Set 16 | khuzdar
# Processing Record 34 of Set 16 | macusani
# Processing Record 35 of Set 16 | sinnai
# Processing Record 36 of Set 16 | terrace bay
# Processing Record 37 of Set 16 | mato verde
# Processing Record 38 of Set 16 | tombouctou
# Processing Record 39 of Set 16 | farafangana
# Processing Record 40 of Set 16 | bonthe
# Processing Record 41 of Set 16 | crotone
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 744

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Dusi  12.7667   79.6833     81.23        77          41
# 1  Puerto Colombia  10.9878  -74.9547     81.97        82          56
# 2   Ribeira Grande  38.5167  -28.7000     61.77        83          98
# 3         Westport  41.1415  -73.3579     61.92        77          10
# 4          Ushuaia -54.8000  -68.3000     32.32        83           0
# 5            Kharp  66.8014   65.8081     36.86        89         100
# 6        Busselton -33.6500  115.3333     59.18        54          60
# 7      Port Alfred -33.5906   26.8910     63.18        96         100
# 8        Cape Town -33.9258   18.4232     62.91        85           0
# 9       Bredasdorp -34.5322   20.0403     57.24        97          99
#
#    Wind Speed Country Current Description
# 0        0.83      IN    scattered clouds
# 1       13.82      CO       broken clouds
# 2        8.99      PT     overcast clouds
# 3        5.99      US           clear sky
# 4        7.18      AR           clear sky
# 5        1.59      RU     overcast clouds
# 6       11.63      AU       broken clouds
# 7        5.01      ZA          light rain
# 8        4.61      ZA           clear sky
# 9        7.20      ZA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Dusi      IN  12.7667   79.6833     81.23        77          41
# 1  Puerto Colombia      CO  10.9878  -74.9547     81.97        82          56
# 2   Ribeira Grande      PT  38.5167  -28.7000     61.77        83          98
# 3         Westport      US  41.1415  -73.3579     61.92        77          10
# 4          Ushuaia      AR -54.8000  -68.3000     32.32        83           0
# 5            Kharp      RU  66.8014   65.8081     36.86        89         100
# 6        Busselton      AU -33.6500  115.3333     59.18        54          60
# 7      Port Alfred      ZA -33.5906   26.8910     63.18        96         100
# 8        Cape Town      ZA -33.9258   18.4232     62.91        85           0
# 9       Bredasdorp      ZA -34.5322   20.0403     57.24        97          99
#
#    Wind Speed Current Description
# 0        0.83    scattered clouds
# 1       13.82       broken clouds
# 2        8.99     overcast clouds
# 3        5.99           clear sky
# 4        7.18           clear sky
# 5        1.59     overcast clouds
# 6       11.63       broken clouds
# 7        5.01          light rain
# 8        4.61           clear sky
# 9        7.20     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label = "City_ID")
