# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 722

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 1 | halifax
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | saint anthony
# Processing Record 5 of Set 1 | tutoia
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | morondava
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | requena
# Processing Record 11 of Set 1 | gamboula
# Processing Record 12 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | umarkot
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | mamallapuram
# Processing Record 17 of Set 1 | birjand
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | nantucket
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | cururupu
# Processing Record 24 of Set 1 | thiruvananthapuram
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | hofn
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | ilhabela
# Processing Record 29 of Set 1 | eirunepe
# Processing Record 30 of Set 1 | elat
# Processing Record 31 of Set 1 | bathsheba
# Processing Record 32 of Set 1 | kedrovyy
# Processing Record 33 of Set 1 | narsaq
# Processing Record 34 of Set 1 | maragogi
# Processing Record 35 of Set 1 | tamandare
# Processing Record 36 of Set 1 | rio gallegos
# Processing Record 37 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 1 | jos
# Processing Record 39 of Set 1 | peniche
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | sangmelima
# Processing Record 42 of Set 1 | grabovo
# Processing Record 43 of Set 1 | araouane
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | nouadhibou
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | tahoua
# Processing Record 50 of Set 1 | lagunas
# Processing Record 1 of Set 2 | kisangani
# Processing Record 2 of Set 2 | campobasso
# Processing Record 3 of Set 2 | conde
# Processing Record 4 of Set 2 | vestmannaeyjar
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 2 | samba
# Processing Record 8 of Set 2 | lodja
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | vila do maio
# Processing Record 11 of Set 2 | hambantota
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | goma
# Processing Record 14 of Set 2 | puksoozero
# Processing Record 15 of Set 2 | santa rosa
# Processing Record 16 of Set 2 | novoagansk
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | havre-saint-pierre
# Processing Record 22 of Set 2 | berlevag
# Processing Record 23 of Set 2 | la palma
# Processing Record 24 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 2 | nizhnevartovsk
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | abu dhabi
# Processing Record 28 of Set 2 | wittenbach
# Processing Record 29 of Set 2 | tahta
# Processing Record 30 of Set 2 | les cayes
# Processing Record 31 of Set 2 | praia
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | fonte boa
# Processing Record 34 of Set 2 | upata
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | trincomalee
# Processing Record 37 of Set 2 | colares
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | malindi
# Processing Record 40 of Set 2 | agirish
# Processing Record 41 of Set 2 | trairi
# Processing Record 42 of Set 2 | hrebinka
# Processing Record 43 of Set 2 | iskateley
# Processing Record 44 of Set 2 | diamantino
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | belmonte
# Processing Record 47 of Set 2 | carutapera
# Processing Record 48 of Set 2 | los llanos de aridane
# Processing Record 49 of Set 2 | matay
# Processing Record 50 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 3 | salalah
# Processing Record 2 of Set 3 | serenje
# Processing Record 3 of Set 3 | port-gentil
# Processing Record 4 of Set 3 | karpogory
# Processing Record 5 of Set 3 | henties bay
# Processing Record 6 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 3 | pitman
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | marsaxlokk
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | touros
# Processing Record 13 of Set 3 | braganca
# Processing Record 14 of Set 3 | gamba
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | mwense
# Processing Record 18 of Set 3 | metsavan
# Processing Record 19 of Set 3 | buraydah
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | takoradi
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | mbanza-ngungu
# Processing Record 24 of Set 3 | omboue
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | shubarkuduk
# Processing Record 27 of Set 3 | kaduqli
# Processing Record 28 of Set 3 | onda
# Processing Record 29 of Set 3 | zemio
# Processing Record 30 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | banapur
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | miquelon
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | vilhena
# Processing Record 37 of Set 3 | chicama
# Processing Record 38 of Set 3 | qaqortoq
# Processing Record 39 of Set 3 | pangnirtung
# Processing Record 40 of Set 3 | iranshahr
# Processing Record 41 of Set 3 | saint george
# Processing Record 42 of Set 3 | cabedelo
# Processing Record 43 of Set 3 | mednogorsk
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | coroico
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | barra patuca
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | kattivakkam
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | sibiti
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | melbu
# Processing Record 6 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 4 | minab
# Processing Record 8 of Set 4 | abu kamal
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | krasnoselkup
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | eydhafushi
# Processing Record 13 of Set 4 | sundargarh
# Processing Record 14 of Set 4 | punta cardon
# Processing Record 15 of Set 4 | haines city
# Processing Record 16 of Set 4 | comodoro rivadavia
# Processing Record 17 of Set 4 | iracoubo
# Processing Record 18 of Set 4 | aksarka
# Processing Record 19 of Set 4 | cayenne
# Processing Record 20 of Set 4 | karoi
# Processing Record 21 of Set 4 | canillo
# Processing Record 22 of Set 4 | ostrovnoy
# Processing Record 23 of Set 4 | san cristobal
# Processing Record 24 of Set 4 | olafsvik
# Processing Record 25 of Set 4 | richards bay
# Processing Record 26 of Set 4 | sagua de tanamo
# Processing Record 27 of Set 4 | cioroiasiu
# City not found. Skipping...
# Processing Record 28 of Set 4 | oranjemund
# Processing Record 29 of Set 4 | villa rica
# Processing Record 30 of Set 4 | general roca
# Processing Record 31 of Set 4 | roald
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | ust-ishim
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | klaksvik
# Processing Record 36 of Set 4 | fort stewart
# Processing Record 37 of Set 4 | agbor
# Processing Record 38 of Set 4 | bandar-e lengeh
# Processing Record 39 of Set 4 | carballo
# Processing Record 40 of Set 4 | harstad
# Processing Record 41 of Set 4 | hobyo
# Processing Record 42 of Set 4 | manono
# Processing Record 43 of Set 4 | tucuman
# Processing Record 44 of Set 4 | urengoy
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | yazman
# Processing Record 47 of Set 4 | shetpe
# Processing Record 48 of Set 4 | teguldet
# Processing Record 49 of Set 4 | rawson
# Processing Record 50 of Set 4 | asfi
# Processing Record 1 of Set 5 | ramhormoz
# Processing Record 2 of Set 5 | muli
# Processing Record 3 of Set 5 | monrovia
# Processing Record 4 of Set 5 | gryazovets
# Processing Record 5 of Set 5 | norrtalje
# Processing Record 6 of Set 5 | waddan
# Processing Record 7 of Set 5 | koslan
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | parrita
# Processing Record 10 of Set 5 | sinnamary
# Processing Record 11 of Set 5 | sept-iles
# Processing Record 12 of Set 5 | mecca
# Processing Record 13 of Set 5 | mitu
# Processing Record 14 of Set 5 | kamwenge
# Processing Record 15 of Set 5 | kudymkar
# Processing Record 16 of Set 5 | muisne
# Processing Record 17 of Set 5 | tala
# Processing Record 18 of Set 5 | saint-francois
# Processing Record 19 of Set 5 | garissa
# Processing Record 20 of Set 5 | sisimiut
# Processing Record 21 of Set 5 | teruel
# Processing Record 22 of Set 5 | foumban
# Processing Record 23 of Set 5 | tefe
# Processing Record 24 of Set 5 | ancud
# Processing Record 25 of Set 5 | aras
# Processing Record 26 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 27 of Set 5 | key west
# Processing Record 28 of Set 5 | camacupa
# Processing Record 29 of Set 5 | staryy nadym
# Processing Record 30 of Set 5 | plettenberg bay
# Processing Record 31 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 5 | mangrol
# Processing Record 33 of Set 5 | bonthe
# Processing Record 34 of Set 5 | geraldton
# Processing Record 35 of Set 5 | tortoli
# Processing Record 36 of Set 5 | tatawin
# Processing Record 37 of Set 5 | itarema
# Processing Record 38 of Set 5 | chambishi
# Processing Record 39 of Set 5 | kazerun
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | doha
# Processing Record 42 of Set 5 | falmouth
# Processing Record 43 of Set 5 | biscarrosse
# Processing Record 44 of Set 5 | sur
# Processing Record 45 of Set 5 | khalilabad
# Processing Record 46 of Set 5 | hornepayne
# Processing Record 47 of Set 5 | natal
# Processing Record 48 of Set 5 | pauini
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | havelock
# Processing Record 1 of Set 6 | zambezi
# Processing Record 2 of Set 6 | korla
# Processing Record 3 of Set 6 | roros
# Processing Record 4 of Set 6 | saint-georges
# Processing Record 5 of Set 6 | lethem
# Processing Record 6 of Set 6 | kutum
# Processing Record 7 of Set 6 | riberalta
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | thinadhoo
# Processing Record 10 of Set 6 | adrar
# Processing Record 11 of Set 6 | haradok
# Processing Record 12 of Set 6 | abu samrah
# Processing Record 13 of Set 6 | muros
# Processing Record 14 of Set 6 | montijo
# Processing Record 15 of Set 6 | pipri
# Processing Record 16 of Set 6 | ibitinga
# Processing Record 17 of Set 6 | brigantine
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | inirida
# Processing Record 20 of Set 6 | cap malheureux
# Processing Record 21 of Set 6 | can
# Processing Record 22 of Set 6 | havoysund
# Processing Record 23 of Set 6 | pastavy
# Processing Record 24 of Set 6 | sarkand
# Processing Record 25 of Set 6 | sambava
# Processing Record 26 of Set 6 | barinas
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 6 | parkersburg
# Processing Record 30 of Set 6 | kidal
# Processing Record 31 of Set 6 | bannu
# Processing Record 32 of Set 6 | mehamn
# Processing Record 33 of Set 6 | oistins
# Processing Record 34 of Set 6 | podyuga
# Processing Record 35 of Set 6 | rokupr
# Processing Record 36 of Set 6 | kaliua
# Processing Record 37 of Set 6 | markala
# Processing Record 38 of Set 6 | qurunbaliyah
# City not found. Skipping...
# Processing Record 39 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 6 | neuquen
# Processing Record 41 of Set 6 | chiredzi
# Processing Record 42 of Set 6 | snasa
# Processing Record 43 of Set 6 | karasjok
# Processing Record 44 of Set 6 | leh
# Processing Record 45 of Set 6 | vargashi
# Processing Record 46 of Set 6 | niquelandia
# Processing Record 47 of Set 6 | thompson
# Processing Record 48 of Set 6 | vardo
# Processing Record 49 of Set 6 | pimentel
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | coleraine
# Processing Record 2 of Set 7 | angoche
# Processing Record 3 of Set 7 | vestmanna
# Processing Record 4 of Set 7 | dingle
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | kholmogory
# Processing Record 7 of Set 7 | forest
# Processing Record 8 of Set 7 | tabas
# Processing Record 9 of Set 7 | monte santo de minas
# Processing Record 10 of Set 7 | darnah
# Processing Record 11 of Set 7 | arlit
# Processing Record 12 of Set 7 | shache
# Processing Record 13 of Set 7 | lifford
# Processing Record 14 of Set 7 | nuzvid
# Processing Record 15 of Set 7 | cravo norte
# Processing Record 16 of Set 7 | kotido
# Processing Record 17 of Set 7 | tazmalt
# Processing Record 18 of Set 7 | hansot
# Processing Record 19 of Set 7 | borujan
# City not found. Skipping...
# Processing Record 20 of Set 7 | pao de acucar
# Processing Record 21 of Set 7 | vallenar
# Processing Record 22 of Set 7 | alta floresta
# Processing Record 23 of Set 7 | soyo
# Processing Record 24 of Set 7 | morant bay
# Processing Record 25 of Set 7 | kasongo-lunda
# Processing Record 26 of Set 7 | altay
# Processing Record 27 of Set 7 | verkhniy avzyan
# Processing Record 28 of Set 7 | harrisburg
# Processing Record 29 of Set 7 | cassia
# Processing Record 30 of Set 7 | bage
# Processing Record 31 of Set 7 | beira
# Processing Record 32 of Set 7 | baherden
# Processing Record 33 of Set 7 | aswan
# Processing Record 34 of Set 7 | dzerzhinsk
# Processing Record 35 of Set 7 | panaba
# Processing Record 36 of Set 7 | nikel
# Processing Record 37 of Set 7 | dakar
# Processing Record 38 of Set 7 | goderich
# Processing Record 39 of Set 7 | zyryanovskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | mayumba
# Processing Record 41 of Set 7 | kamenka
# Processing Record 42 of Set 7 | matagami
# Processing Record 43 of Set 7 | bobo dioulasso
# Processing Record 44 of Set 7 | bana
# Processing Record 45 of Set 7 | husavik
# Processing Record 46 of Set 7 | valdivia
# Processing Record 47 of Set 7 | salinopolis
# Processing Record 48 of Set 7 | bubaque
# Processing Record 49 of Set 7 | mabaruma
# Processing Record 50 of Set 7 | nagapattinam
# Processing Record 1 of Set 8 | rovereto
# Processing Record 2 of Set 8 | mahibadhoo
# Processing Record 3 of Set 8 | lebu
# Processing Record 4 of Set 8 | sorland
# Processing Record 5 of Set 8 | lisburn
# Processing Record 6 of Set 8 | prado
# Processing Record 7 of Set 8 | kanniyakumari
# Processing Record 8 of Set 8 | ortakoy
# Processing Record 9 of Set 8 | shahreza
# Processing Record 10 of Set 8 | fasa
# Processing Record 11 of Set 8 | paita
# Processing Record 12 of Set 8 | saint-pierre
# Processing Record 13 of Set 8 | pinheiro machado
# Processing Record 14 of Set 8 | usak
# Processing Record 15 of Set 8 | palaikastron
# Processing Record 16 of Set 8 | daura
# Processing Record 17 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 8 | edd
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | samur
# Processing Record 21 of Set 8 | faya
# Processing Record 22 of Set 8 | san andres
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | gambo
# Processing Record 25 of Set 8 | podor
# Processing Record 26 of Set 8 | kortkeros
# Processing Record 27 of Set 8 | malanje
# Processing Record 28 of Set 8 | goycay
# City not found. Skipping...
# Processing Record 29 of Set 8 | masunga
# Processing Record 30 of Set 8 | zaysan
# Processing Record 31 of Set 8 | cockburn town
# Processing Record 32 of Set 8 | caala
# Processing Record 33 of Set 8 | albany
# Processing Record 34 of Set 8 | andarab
# City not found. Skipping...
# Processing Record 35 of Set 8 | lyantonde
# Processing Record 36 of Set 8 | santa cruz cabralia
# Processing Record 37 of Set 8 | san benedetto del tronto
# Processing Record 38 of Set 8 | viedma
# Processing Record 39 of Set 8 | gebze
# Processing Record 40 of Set 8 | aktash
# Processing Record 41 of Set 8 | seminole
# Processing Record 42 of Set 8 | madimba
# Processing Record 43 of Set 8 | oktyabrskoye
# Processing Record 44 of Set 8 | catamarca
# Processing Record 45 of Set 8 | svetlyy
# Processing Record 46 of Set 8 | ibipeba
# Processing Record 47 of Set 8 | marystown
# Processing Record 48 of Set 8 | sussex
# Processing Record 49 of Set 8 | boyuibe
# Processing Record 50 of Set 8 | yeovil
# Processing Record 1 of Set 9 | hualmay
# Processing Record 2 of Set 9 | san ramon
# Processing Record 3 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | shu
# Processing Record 6 of Set 9 | banda aceh
# Processing Record 7 of Set 9 | den helder
# Processing Record 8 of Set 9 | atar
# Processing Record 9 of Set 9 | cuenca
# Processing Record 10 of Set 9 | santiago del estero
# Processing Record 11 of Set 9 | jalu
# Processing Record 12 of Set 9 | xai-xai
# Processing Record 13 of Set 9 | sultanpur
# Processing Record 14 of Set 9 | hamina
# Processing Record 15 of Set 9 | cobija
# Processing Record 16 of Set 9 | yar-sale
# Processing Record 17 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 18 of Set 9 | barra do garcas
# Processing Record 19 of Set 9 | chapayevka
# Processing Record 20 of Set 9 | moose factory
# Processing Record 21 of Set 9 | kamina
# Processing Record 22 of Set 9 | senno
# Processing Record 23 of Set 9 | siyabuswa
# Processing Record 24 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 25 of Set 9 | marawi
# Processing Record 26 of Set 9 | usinsk
# Processing Record 27 of Set 9 | centenario do sul
# Processing Record 28 of Set 9 | karatau
# Processing Record 29 of Set 9 | zhanakorgan
# Processing Record 30 of Set 9 | la paz
# Processing Record 31 of Set 9 | hohoe
# Processing Record 32 of Set 9 | sillod
# Processing Record 33 of Set 9 | maceio
# Processing Record 34 of Set 9 | praia da vitoria
# Processing Record 35 of Set 9 | alibag
# Processing Record 36 of Set 9 | paragominas
# Processing Record 37 of Set 9 | mongo
# Processing Record 38 of Set 9 | zhurivka
# Processing Record 39 of Set 9 | manzil salim
# Processing Record 40 of Set 9 | kalemie
# Processing Record 41 of Set 9 | palpa
# Processing Record 42 of Set 9 | lugovoy
# Processing Record 43 of Set 9 | bonavista
# Processing Record 44 of Set 9 | constitucion
# Processing Record 45 of Set 9 | pala
# Processing Record 46 of Set 9 | la tuque
# Processing Record 47 of Set 9 | bolshaya atnya
# City not found. Skipping...
# Processing Record 48 of Set 9 | blyznyuky
# Processing Record 49 of Set 9 | stanghelle
# Processing Record 50 of Set 9 | ambilobe
# Processing Record 1 of Set 10 | bosaso
# Processing Record 2 of Set 10 | kekri
# Processing Record 3 of Set 10 | gao
# Processing Record 4 of Set 10 | ribas do rio pardo
# Processing Record 5 of Set 10 | mandiana
# Processing Record 6 of Set 10 | middle island
# Processing Record 7 of Set 10 | sint-laureins
# Processing Record 8 of Set 10 | esil
# Processing Record 9 of Set 10 | llangefni
# Processing Record 10 of Set 10 | margate
# Processing Record 11 of Set 10 | redcar
# Processing Record 12 of Set 10 | kaniama
# Processing Record 13 of Set 10 | mali zvornik
# Processing Record 14 of Set 10 | ewo
# Processing Record 15 of Set 10 | grindavik
# Processing Record 16 of Set 10 | westport
# Processing Record 17 of Set 10 | nicoya
# Processing Record 18 of Set 10 | wukari
# Processing Record 19 of Set 10 | opobo
# City not found. Skipping...
# Processing Record 20 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 10 | tsaratanana
# Processing Record 22 of Set 10 | elmadag
# Processing Record 23 of Set 10 | maniitsoq
# Processing Record 24 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 10 | camopi
# Processing Record 26 of Set 10 | presidencia roque saenz pena
# Processing Record 27 of Set 10 | saint-ambroise
# Processing Record 28 of Set 10 | hagerstown
# Processing Record 29 of Set 10 | gemena
# Processing Record 30 of Set 10 | kayes
# Processing Record 31 of Set 10 | le port
# Processing Record 32 of Set 10 | pachino
# Processing Record 33 of Set 10 | caceres
# Processing Record 34 of Set 10 | moncao
# Processing Record 35 of Set 10 | forssa
# Processing Record 36 of Set 10 | sitio novo do tocantins
# Processing Record 37 of Set 10 | bay roberts
# Processing Record 38 of Set 10 | la asuncion
# Processing Record 39 of Set 10 | filadelfia
# Processing Record 40 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | akdagmadeni
# Processing Record 43 of Set 10 | antofagasta
# Processing Record 44 of Set 10 | traverse city
# Processing Record 45 of Set 10 | partenit
# Processing Record 46 of Set 10 | korem
# Processing Record 47 of Set 10 | sao jose da coroa grande
# Processing Record 48 of Set 10 | gagra
# Processing Record 49 of Set 10 | izhmorskiy
# Processing Record 50 of Set 10 | kedarnath
# City not found. Skipping...
# Processing Record 1 of Set 11 | bolotnoye
# Processing Record 2 of Set 11 | la rioja
# Processing Record 3 of Set 11 | road town
# Processing Record 4 of Set 11 | severnyy
# Processing Record 5 of Set 11 | maarianhamina
# Processing Record 6 of Set 11 | goundam
# Processing Record 7 of Set 11 | miraflores
# Processing Record 8 of Set 11 | sistranda
# Processing Record 9 of Set 11 | saint-paul
# Processing Record 10 of Set 11 | malakal
# Processing Record 11 of Set 11 | waynesville
# Processing Record 12 of Set 11 | sarh
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | gazanjyk
# Processing Record 15 of Set 11 | bolshoye selo
# Processing Record 16 of Set 11 | antalaha
# Processing Record 17 of Set 11 | tete
# Processing Record 18 of Set 11 | isiro
# Processing Record 19 of Set 11 | umtata
# Processing Record 20 of Set 11 | sayan
# Processing Record 21 of Set 11 | waynesboro
# Processing Record 22 of Set 11 | sembe
# Processing Record 23 of Set 11 | krasnaya gora
# Processing Record 24 of Set 11 | tessalit
# Processing Record 25 of Set 11 | iralaya
# Processing Record 26 of Set 11 | kulhudhuffushi
# Processing Record 27 of Set 11 | murdochville
# Processing Record 28 of Set 11 | marsh harbour
# Processing Record 29 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 11 | igrim
# Processing Record 31 of Set 11 | sovata
# Processing Record 32 of Set 11 | sokoto
# Processing Record 33 of Set 11 | bereda
# Processing Record 34 of Set 11 | burica
# City not found. Skipping...
# Processing Record 35 of Set 11 | beloha
# Processing Record 36 of Set 11 | irbit
# Processing Record 37 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 11 | costinesti
# Processing Record 39 of Set 11 | ustye
# Processing Record 40 of Set 11 | riachao do jacuipe
# Processing Record 41 of Set 11 | plouzane
# Processing Record 42 of Set 11 | tabou
# Processing Record 43 of Set 11 | diu
# Processing Record 44 of Set 11 | honningsvag
# Processing Record 45 of Set 11 | padang
# Processing Record 46 of Set 11 | chateau-gontier
# Processing Record 47 of Set 11 | bud
# Processing Record 48 of Set 11 | yambio
# Processing Record 49 of Set 11 | sorkjosen
# Processing Record 50 of Set 11 | odweyne
# Processing Record 1 of Set 12 | linguere
# Processing Record 2 of Set 12 | tazovskiy
# Processing Record 3 of Set 12 | soloneshnoye
# Processing Record 4 of Set 12 | toguchin
# Processing Record 5 of Set 12 | carlibaba
# Processing Record 6 of Set 12 | liverpool
# Processing Record 7 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 8 of Set 12 | bhuban
# Processing Record 9 of Set 12 | harper
# Processing Record 10 of Set 12 | tacuarembo
# Processing Record 11 of Set 12 | pailon
# Processing Record 12 of Set 12 | the valley
# Processing Record 13 of Set 12 | santa isabel do rio negro
# Processing Record 14 of Set 12 | ludwigsfelde
# Processing Record 15 of Set 12 | nokha
# Processing Record 16 of Set 12 | barra do bugres
# Processing Record 17 of Set 12 | raga
# Processing Record 18 of Set 12 | eseka
# Processing Record 19 of Set 12 | benicarlo
# Processing Record 20 of Set 12 | rabo de peixe
# Processing Record 21 of Set 12 | sao felix do xingu
# Processing Record 22 of Set 12 | puerto quijarro
# Processing Record 23 of Set 12 | mount pleasant
# Processing Record 24 of Set 12 | sao paulo de olivenca
# Processing Record 25 of Set 12 | mattawa
# Processing Record 26 of Set 12 | joao pessoa
# Processing Record 27 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 28 of Set 12 | jijiga
# Processing Record 29 of Set 12 | viterbo
# Processing Record 30 of Set 12 | terre-de-bas
# Processing Record 31 of Set 12 | fecamp
# Processing Record 32 of Set 12 | lucea
# Processing Record 33 of Set 12 | kautokeino
# Processing Record 34 of Set 12 | axim
# Processing Record 35 of Set 12 | porto walter
# Processing Record 36 of Set 12 | farmington
# Processing Record 37 of Set 12 | camabatela
# Processing Record 38 of Set 12 | cordoba
# Processing Record 39 of Set 12 | bilma
# Processing Record 40 of Set 12 | sachin
# Processing Record 41 of Set 12 | voi
# Processing Record 42 of Set 12 | krutinka
# Processing Record 43 of Set 12 | portoferraio
# Processing Record 44 of Set 12 | diffa
# Processing Record 45 of Set 12 | jaciara
# Processing Record 46 of Set 12 | santa fe
# Processing Record 47 of Set 12 | new albany
# Processing Record 48 of Set 12 | marquette
# Processing Record 49 of Set 12 | san ignacio
# Processing Record 50 of Set 12 | oxford
# Processing Record 1 of Set 13 | sunyani
# Processing Record 2 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 13 | saint-augustin
# Processing Record 4 of Set 13 | chabahar
# Processing Record 5 of Set 13 | bojnurd
# Processing Record 6 of Set 13 | gossas
# Processing Record 7 of Set 13 | kralendijk
# Processing Record 8 of Set 13 | ballina
# Processing Record 9 of Set 13 | gonaives
# Processing Record 10 of Set 13 | zhezkazgan
# Processing Record 11 of Set 13 | nioki
# Processing Record 12 of Set 13 | bassum
# Processing Record 13 of Set 13 | ouesso
# Processing Record 14 of Set 13 | riga
# Processing Record 15 of Set 13 | nosy varika
# Processing Record 16 of Set 13 | acarau
# Processing Record 17 of Set 13 | yokadouma
# Processing Record 18 of Set 13 | morropon
# Processing Record 19 of Set 13 | burayevo
# Processing Record 20 of Set 13 | talnakh
# Processing Record 21 of Set 13 | tawzar
# City not found. Skipping...
# Processing Record 22 of Set 13 | lajeado
# Processing Record 23 of Set 13 | nuuk
# Processing Record 24 of Set 13 | dapaong
# Processing Record 25 of Set 13 | raudeberg
# Processing Record 26 of Set 13 | kulebaki
# Processing Record 27 of Set 13 | tostedt
# Processing Record 28 of Set 13 | port hawkesbury
# Processing Record 29 of Set 13 | malkara
# Processing Record 30 of Set 13 | palitana
# Processing Record 31 of Set 13 | aquiraz
# Processing Record 32 of Set 13 | joshimath
# Processing Record 33 of Set 13 | springdale
# Processing Record 34 of Set 13 | izhma
# Processing Record 35 of Set 13 | yol
# Processing Record 36 of Set 13 | lubango
# Processing Record 37 of Set 13 | kapustin yar-1
# City not found. Skipping...
# Processing Record 38 of Set 13 | eregli
# Processing Record 39 of Set 13 | ploemeur
# Processing Record 40 of Set 13 | la sarre
# Processing Record 41 of Set 13 | malkangiri
# Processing Record 42 of Set 13 | nowy dwor mazowiecki
# Processing Record 43 of Set 13 | ullapool
# Processing Record 44 of Set 13 | amapa
# Processing Record 45 of Set 13 | colonial park
# Processing Record 46 of Set 13 | leon
# Processing Record 47 of Set 13 | saint-leu
# Processing Record 48 of Set 13 | umm lajj
# Processing Record 49 of Set 13 | charagua
# Processing Record 50 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 1 of Set 14 | kontagora
# Processing Record 2 of Set 14 | petrivka
# Processing Record 3 of Set 14 | killybegs
# Processing Record 4 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 14 | kuytun
# Processing Record 6 of Set 14 | bindura
# Processing Record 7 of Set 14 | banikoara
# Processing Record 8 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 9 of Set 14 | sotuta
# Processing Record 10 of Set 14 | tendukheda
# Processing Record 11 of Set 14 | port blair
# Processing Record 12 of Set 14 | kyabe
# Processing Record 13 of Set 14 | pokhara
# Processing Record 14 of Set 14 | kulu
# Processing Record 15 of Set 14 | janauba
# Processing Record 16 of Set 14 | brae
# Processing Record 17 of Set 14 | albert town
# Processing Record 18 of Set 14 | san vicente de canete
# Processing Record 19 of Set 14 | ayorou
# Processing Record 20 of Set 14 | imbituba
# Processing Record 21 of Set 14 | winchester
# Processing Record 22 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 23 of Set 14 | dudinka
# Processing Record 24 of Set 14 | kargasok
# Processing Record 25 of Set 14 | merthyr tydfil
# Processing Record 26 of Set 14 | curaca
# Processing Record 27 of Set 14 | chhindwara
# Processing Record 28 of Set 14 | trujillo
# Processing Record 29 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 30 of Set 14 | awbari
# Processing Record 31 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 14 | laguna
# Processing Record 33 of Set 14 | itatskiy
# Processing Record 34 of Set 14 | brazzaville
# Processing Record 35 of Set 14 | selma
# Processing Record 36 of Set 14 | gat
# Processing Record 37 of Set 14 | gasa
# Processing Record 38 of Set 14 | bria
# Processing Record 39 of Set 14 | ilebo
# Processing Record 40 of Set 14 | najran
# Processing Record 41 of Set 14 | arkhangelsk
# Processing Record 42 of Set 14 | kongwa
# Processing Record 43 of Set 14 | uruzgan
# Processing Record 44 of Set 14 | luanda
# Processing Record 45 of Set 14 | shubarshi
# Processing Record 46 of Set 14 | tamara
# Processing Record 47 of Set 14 | sagua la grande
# Processing Record 48 of Set 14 | saint-louis
# Processing Record 49 of Set 14 | lokosovo
# Processing Record 50 of Set 14 | pindwara
# Processing Record 1 of Set 15 | kurtamysh
# Processing Record 2 of Set 15 | kudahuvadhoo
# Processing Record 3 of Set 15 | manhush
# Processing Record 4 of Set 15 | bomet
# Processing Record 5 of Set 15 | ofaqim
# Processing Record 6 of Set 15 | abha
# Processing Record 7 of Set 15 | mercedes
# Processing Record 8 of Set 15 | luis correia
# Processing Record 9 of Set 15 | knysna
# Processing Record 10 of Set 15 | saquena
# Processing Record 11 of Set 15 | baranain
# Processing Record 12 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | masakin
# Processing Record 14 of Set 15 | iquique
# Processing Record 15 of Set 15 | kirillov
# Processing Record 16 of Set 15 | tabuk
# Processing Record 17 of Set 15 | gornopravdinsk
# Processing Record 18 of Set 15 | burgthann
# Processing Record 19 of Set 15 | vorobyevka
# Processing Record 20 of Set 15 | puerto leguizamo
# Processing Record 21 of Set 15 | maturin
# Processing Record 22 of Set 15 | abadan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 670

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Halifax  44.6453  -63.5724     67.89        84          40
# 1  Arraial Do Cabo -22.9661  -42.0278     73.15        86          20
# 2    Saint Anthony  45.0205  -93.2180     39.24        45          40
# 3           Tutoia  -2.7619  -42.2744     83.12        72          10
# 4        Carnarvon -24.8667  113.6333     63.97        62           0
# 5        Morondava -20.2833   44.2833     77.43        78           5
# 6          Iqaluit  63.7506  -68.5145     32.70        69         100
# 7         Hermanus -34.4187   19.2345     63.81        95          62
# 8          Requena  39.4883   -1.1004     63.79        85          97
# 9         Gamboula   4.1178   15.1393     69.85        94          88
#
#    Wind Speed Country Current Description
# 0       10.36      CA                 fog
# 1       16.78      BR          few clouds
# 2       17.27      US    scattered clouds
# 3       15.32      BR           clear sky
# 4       20.24      AU           clear sky
# 5       14.72      MG           clear sky
# 6       15.99      CA     overcast clouds
# 7        3.89      ZA       broken clouds
# 8        4.25      ES     overcast clouds
# 9        0.87      CF     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Halifax      CA  44.6453  -63.5724     67.89        84          40
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     73.15        86          20
# 2    Saint Anthony      US  45.0205  -93.2180     39.24        45          40
# 3           Tutoia      BR  -2.7619  -42.2744     83.12        72          10
# 4        Carnarvon      AU -24.8667  113.6333     63.97        62           0
# 5        Morondava      MG -20.2833   44.2833     77.43        78           5
# 6          Iqaluit      CA  63.7506  -68.5145     32.70        69         100
# 7         Hermanus      ZA -34.4187   19.2345     63.81        95          62
# 8          Requena      ES  39.4883   -1.1004     63.79        85          97
# 9         Gamboula      CF   4.1178   15.1393     69.85        94          88
#
#    Wind Speed Current Description
# 0       10.36                 fog
# 1       16.78          few clouds
# 2       17.27    scattered clouds
# 3       15.32           clear sky
# 4       20.24           clear sky
# 5       14.72           clear sky
# 6       15.99     overcast clouds
# 7        3.89       broken clouds
# 8        4.25     overcast clouds
# 9        0.87     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label = "City_ID")
